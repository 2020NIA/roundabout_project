# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('/Users/yangdongjae/Desktop/2020/대외활동/2020년 공공 빅데이터 청년 인턴십/실무형 프로젝트/roundabout_project/data/2017청주 교차로_prep.csv', encoding = 'cp949')

# %%
df.set_index(['교차로명'])
# Out:
#             통행량    좌회전 비율8   좌회전 비율13   좌회전 비율18  사고건수  \
# 교차로명
# 흥덕4       12093  17.660000  18.260000  20.060000     8
# 현도면사무소3    6285  18.294190  13.341724   7.051565     3
# 효촌분기점3     8752  32.332633  25.972342  34.019955     0
# 터미널4      19712   7.365398   6.701429   6.856916    10
# 하이닉스반도체4  13278  18.630000  19.710000  18.360000     6
# ...         ...        ...        ...        ...   ...
# 석판분기점4     4470  28.810000  25.590000  39.400000     1
# 서문교하상도로3   4499  19.332566  28.961039  30.989453     3
# 서청주교4     17604  30.930000  25.170000  23.480000     7
# 산업단지6     12080  16.054937  14.000596  19.555556    11
# 상당4       14056  21.660000  20.680000  22.920000     4
#
#           교차로 반경 50m 내 무인교통단속카메라 수  교차로 반경 50m 내 신호등 수  교차로 반경 50m 내 신호등 유무
# 교차로명
# 흥덕4                              0                   0                    0
# 현도면사무소3                          2                   0                    0
# 효촌분기점3                           0                   0                    0
# 터미널4                             0                   2                    1
# 하이닉스반도체4                         0                   2                    1
# ...                            ...                 ...                  ...
# 석판분기점4                           0                   0                    0
# 서문교하상도로3                         0                   6                    1
# 서청주교4                            0                   3                    1
# 산업단지6                            1                   3                    1
# 상당4                              0                  12                    1
#
# [70 rows x 8 columns]

# %%
scaler = MinMaxScaler()
df_scaler = scaler.fit_transform(df['통행량'].values.reshape(-1,1))
df.drop(columns = ['통행량'], inplace = True)

# %%
df.drop(columns = ['교차로명'],inplace = True)
# Out:
# -------------------------------------------------------------------
# KeyError                          Traceback (most recent call last)
# <ipython-input-62-3349ecd5ee76> in <module>
# ----> 1 df.drop(columns = ['교차로명'],inplace = True)
#       2 df.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "['교차로명'] not found in axis"

# %%
df.head()
# Out:
#      좌회전 비율8   좌회전 비율13   좌회전 비율18  사고건수  교차로 반경 50m 내 무인교통단속카메라 수  \
# 0  17.660000  18.260000  20.060000     8                         0
# 1  18.294190  13.341724   7.051565     3                         2
# 2  32.332633  25.972342  34.019955     0                         0
# 3   7.365398   6.701429   6.856916    10                         0
# 4  18.630000  19.710000  18.360000     6                         0
#
#    교차로 반경 50m 내 신호등 수  교차로 반경 50m 내 신호등 유무
# 0                   0                    0
# 1                   0                    0
# 2                   0                    0
# 3                   2                    1
# 4                   2                    1

# %%
df_scaler = pd.DataFrame(df_scaler)

# %%
df = pd.concat([df, df_scaler], axis = 1)
# Out:
# -------------------------------------------------------------------
# AttributeError                    Traceback (most recent call last)
# <ipython-input-89-d7c562abeef7> in <module>
# ----> 1 df = pd.concat([df, df_scaler], axis = 1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
df
# Out:
#       좌회전 비율8   좌회전 비율13   좌회전 비율18  사고건수  교차로 반경 50m 내 무인교통단속카메라 수  \
# 0   17.660000  18.260000  20.060000     8                         0
# 1   18.294190  13.341724   7.051565     3                         2
# 2   32.332633  25.972342  34.019955     0                         0
# 3    7.365398   6.701429   6.856916    10                         0
# 4   18.630000  19.710000  18.360000     6                         0
# ..        ...        ...        ...   ...                       ...
# 65  28.810000  25.590000  39.400000     1                         0
# 66  19.332566  28.961039  30.989453     3                         0
# 67  30.930000  25.170000  23.480000     7                         0
# 68  16.054937  14.000596  19.555556    11                         1
# 69  21.660000  20.680000  22.920000     4                         0
#
#     교차로 반경 50m 내 신호등 수  교차로 반경 50m 내 신호등 유무         0
# 0                    0                    0  0.547485
# 1                    0                    0  0.202530
# 2                    0                    0  0.349053
# 3                    2                    1  1.000000
# 4                    2                    1  0.617865
# ..                 ...                  ...       ...
# 65                   0                    0  0.094732
# 66                   6                    1  0.096454
# 67                   3                    1  0.874800
# 68                   3                    1  0.546713
# 69                  12                    1  0.664073
#
# [70 rows x 8 columns]

# %%
df = df.rename({"0":"y"},axis = 1)
# Out:
#       좌회전 비율8   좌회전 비율13   좌회전 비율18  사고건수  교차로 반경 50m 내 무인교통단속카메라 수  \
# 0   17.660000  18.260000  20.060000     8                         0
# 1   18.294190  13.341724   7.051565     3                         2
# 2   32.332633  25.972342  34.019955     0                         0
# 3    7.365398   6.701429   6.856916    10                         0
# 4   18.630000  19.710000  18.360000     6                         0
# ..        ...        ...        ...   ...                       ...
# 65  28.810000  25.590000  39.400000     1                         0
# 66  19.332566  28.961039  30.989453     3                         0
# 67  30.930000  25.170000  23.480000     7                         0
# 68  16.054937  14.000596  19.555556    11                         1
# 69  21.660000  20.680000  22.920000     4                         0
#
#     교차로 반경 50m 내 신호등 수  교차로 반경 50m 내 신호등 유무         0
# 0                    0                    0  0.547485
# 1                    0                    0  0.202530
# 2                    0                    0  0.349053
# 3                    2                    1  1.000000
# 4                    2                    1  0.617865
# ..                 ...                  ...       ...
# 65                   0                    0  0.094732
# 66                   6                    1  0.096454
# 67                   3                    1  0.874800
# 68                   3                    1  0.546713
# 69                  12                    1  0.664073
#
# [70 rows x 8 columns]
